# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
datos = pd.read_csv("assets/datanueva.csv", index_col="ID")
datos.head(10)
# Out:
#                                      Series_Title  \
# ID
# 1                        The Shawshank Redemption
# 2                                   The Godfather
# 3                                 The Dark Knight
# 4                          The Godfather: Part II
# 5                                    12 Angry Men
# 6   The Lord of the Rings: The Return of the King
# 7                                    Pulp Fiction
# 8                                Schindler's List
# 9                                       Inception
# 10                                     Fight Club
#
#                                           Poster_Link Released_Year  \
# ID
# 1   https://m.media-amazon.com/images/M/MV5BMDFkYT...          1994
# 2   https://m.media-amazon.com/images/M/MV5BM2MyNj...          1972
# 3   https://m.media-amazon.com/images/M/MV5BMTMxNT...          2008
# 4   https://m.media-amazon.com/images/M/MV5BMWMwMG...          1974
# ...

# %% [markdown]
# <h4><b>A</b></h4>

# %%
datos.isnull().any()
# Out:
# Series_Title     False
# Poster_Link      False
# Released_Year    False
# Certificate       True
# Runtime          False
# Genre            False
# IMDB_Rating      False
# Overview         False
# Meta_score        True
# Director         False
# Star1            False
# Star2            False
# Star3            False
# Star4            False
# No_of_Votes      False
# Gross             True
# dtype: bool

# %%
datos["Certificate"].isnull()
# Out:
# ID
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
#         ...
# 996     False
# 997     False
# 998     False
# 999      True
# 1000     True
# Name: Certificate, Length: 1000, dtype: bool

# %%
datos["Meta_score"].isnull()
# Out:
# ID
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
#         ...
# 996     False
# 997     False
# 998     False
# 999     False
# 1000    False
# Name: Meta_score, Length: 1000, dtype: bool

# %% [markdown]
# <h4><b>B</b></h4>

# %%
datos_null=datos.dropna()
datos_null
# Out:
#                  Series_Title  \
# ID
# 1    The Shawshank Redemption
# 2               The Godfather
# 3             The Dark Knight
# 4      The Godfather: Part II
# 5                12 Angry Men
# ..                        ...
# 991              Giù la testa
# 992            Kelly's Heroes
# 993           The Jungle Book
# 995        A Hard Day's Night
# 998     From Here to Eternity
#
#                                            Poster_Link Released_Year  \
# ID
# 1    https://m.media-amazon.com/images/M/MV5BMDFkYT...          1994
# 2    https://m.media-amazon.com/images/M/MV5BM2MyNj...          1972
# 3    https://m.media-amazon.com/images/M/MV5BMTMxNT...          2008
# 4    https://m.media-amazon.com/images/M/MV5BMWMwMG...          1974
# 5    https://m.media-amazon.com/images/M/MV5BMWU4N2...          1957
# ..                                                 ...           ...
# 991  https://m.media-amazon.com/images/M/MV5BYjRmY2...          1971
# ...

# %%
datos_null.to_csv('assets/datos_null.csv', index=False)

# %% [markdown]
# <h4><b>C</b></h4>

# %%
# # datos_null.groupby(['Director'],
# a=datos_null[datos_null['Director']]['Meta_score']


# a

# %% [markdown]
# <h4><b>D</b></h4>

# %%
dataframewar=datos_null[datos_null['Genre'].apply(lambda x: 'War'in x)]
dataframewar.head(10)
# Out:
#               Series_Title                                        Poster_Link  \
# ID
# 25     Saving Private Ryan  https://m.media-amazon.com/images/M/MV5BZjhkMD...
# 51              Casablanca  https://m.media-amazon.com/images/M/MV5BY2IzZG...
# 75          Apocalypse Now  https://m.media-amazon.com/images/M/MV5BMDdhOD...
# 85                    1917  https://m.media-amazon.com/images/M/MV5BOTdmNT...
# 91               Incendies  https://m.media-amazon.com/images/M/MV5BMWE3MG...
# 94    Inglourious Basterds  https://m.media-amazon.com/images/M/MV5BOTJiND...
# 105      Full Metal Jacket  https://m.media-amazon.com/images/M/MV5BNzkxOD...
# 151        Pan's Labyrinth  https://m.media-amazon.com/images/M/MV5BMTU3OD...
# 173                    Ran  https://m.media-amazon.com/images/M/MV5BZDBjZT...
# 237  Taegukgi hwinalrimyeo  https://m.media-amazon.com/images/M/MV5BNjAxZT...
#
#     Released_Year Certificate  Runtime                  Genre  IMDB_Rating  \
# ID
# ...

# %%
dataframewar.to_csv('assets/dataframewar.csv', index=False)

# %% [markdown]
# <h4><b>E</b></h4>

# %%
dataframewar_10=dataframewar.head(10)

dataframewar_10.set_index(dataframewar_10['Series_Title'], inplace=True)

plt.bar(np.arange(len(dataframewar_10)) +0.2, dataframewar_10['IMDB_Rating'],0.4,label='IMDB Rating')
plt.bar(np.arange(len(dataframewar_10)) -0.2, dataframewar_10['Meta_score'],0.4,label='Meta Score')

plt.legend()
